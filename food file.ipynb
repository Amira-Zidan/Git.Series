# %%
import pandas as pd

# %%
df = pd.read_excel(r"Z:\food_1.xlsx")
df
# Out:
#    Unnamed: 0 Unnamed: 1     Unnamed: 2         Unnamed: 3      Unnamed: 4  \
# 0         NaN        NaN            NaN                NaN             NaN
# 1  first name  last name  favorite food  favorite desserts  number of days
# 2        ramy      ahmed           rice          ice cream               3
# 3        ramy      ahmed           fish          ice cream               3
# 4       yamen       ramy          Pasta       orange juice               5
# 5       yamen       ramy           meet       orange juice               5
# 6       malek       ramy        chicken              apple               7
#
#   Unnamed: 5
# 0        NaN
# 1      check
# 2        300
# 3        500
# 4        600
# 5        600
# 6       1000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  6 non-null      object
#  1   Unnamed: 1  6 non-null      object
#  2   Unnamed: 2  6 non-null      object
#  3   Unnamed: 3  6 non-null      object
#  4   Unnamed: 4  6 non-null      object
#  5   Unnamed: 5  6 non-null      object
# dtypes: object(6)
# memory usage: 468.0+ bytes

# %%
print(df)
# Out:
#    Unnamed: 0 Unnamed: 1     Unnamed: 2         Unnamed: 3      Unnamed: 4  \
# 0         NaN        NaN            NaN                NaN             NaN
# 1  first name  last name  favorite food  favorite desserts  number of days
# 2        ramy      ahmed           rice          ice cream               3
# 3        ramy      ahmed           fish          ice cream               3
# 4       yamen       ramy          Pasta       orange juice               5
# 5       yamen       ramy           meet       orange juice               5
# 6       malek       ramy        chicken              apple               7
#
#   Unnamed: 5
# 0        NaN
# 1      check
# 2        300
# 3        500
# 4        600
# 5        600
# 6       1000

# %%
df = pd.read_excel(r"Z:\food_1.xlsx", header=2)
df
# Out:
#   first name last name favorite food favorite desserts  number of days  check
# 0       ramy     ahmed          rice         ice cream               3    300
# 1       ramy     ahmed          fish         ice cream               3    500
# 2      yamen      ramy         Pasta      orange juice               5    600
# 3      yamen      ramy          meet      orange juice               5    600
# 4      malek      ramy       chicken             apple               7   1000

# %%
df.set_index('favorite food', inplace=True)
df
# Out:
#               first name last name favorite desserts  number of days  check
# favorite food
# rice                ramy     ahmed         ice cream               3    300
# fish                ramy     ahmed         ice cream               3    500
# Pasta              yamen      ramy      orange juice               5    600
# meet               yamen      ramy      orange juice               5    600
# chicken            malek      ramy             apple               7   1000

# %%
df.drop_duplicates()
# Out:
#               first name last name favorite desserts  number of days  check
# favorite food
# rice                ramy     ahmed         ice cream               3    300
# fish                ramy     ahmed         ice cream               3    500
# Pasta              yamen      ramy      orange juice               5    600
# chicken            malek      ramy             apple               7   1000

# %%
# إضافة عمود جديد باسم "notes" مع قيم فارغة كمثال توضيحي
df['notes'] = ''

# عرض الجدول بعد إضافة العمود الجديد
df

# %%
# إضافة عمود "age" إلى الجدول مع القيم المطلوبة
df['age'] = ['40', '40', '10', '12', '']  # يجب أن يكون عدد القيم مساوي لعدد الصفوف

# عرض الجدول بعد إضافة العمود الجديد
df

# %%
df
# Out:
#               first name last name favorite desserts  number of days  check
# favorite food
# rice                ramy     ahmed         ice cream               3    300
# fish                ramy     ahmed         ice cream               3    500
# Pasta              yamen      ramy      orange juice               5    600
# meet               yamen      ramy      orange juice               5    600
# chicken            malek      ramy             apple               7   1000

# %%
df['age'] = ['40', '40', '10', '10', '12'] 
df
# Out:
#               first name last name favorite desserts  number of days  check  \
# favorite food
# rice                ramy     ahmed         ice cream               3    300
# fish                ramy     ahmed         ice cream               3    500
# Pasta              yamen      ramy      orange juice               5    600
# meet               yamen      ramy      orange juice               5    600
# chicken            malek      ramy             apple               7   1000
#
#               age
# favorite food
# rice           40
# fish           40
# Pasta          10
# meet           10
# chicken        12

# %%
عايزة اكرر الrows اللي في colums number of days بعدد الايام في كل يوم
df = df.loc[df.index.repeat(df['number of days'])]
# Out:
#   Cell In[15], line 1
#     عايزة اكرر الrows اللي في colums number of days بعدد الايام في كل يوم
#           ^
# SyntaxError: invalid syntax

# %%
df = df.loc[df.index.repeat(df['number of days'])]
df
# Out:
#               first name last name favorite desserts  number of days  check  \
# favorite food
# rice                ramy     ahmed         ice cream               3    300
# rice                ramy     ahmed         ice cream               3    300
# rice                ramy     ahmed         ice cream               3    300
# fish                ramy     ahmed         ice cream               3    500
# fish                ramy     ahmed         ice cream               3    500
# fish                ramy     ahmed         ice cream               3    500
# Pasta              yamen      ramy      orange juice               5    600
# Pasta              yamen      ramy      orange juice               5    600
# Pasta              yamen      ramy      orange juice               5    600
# Pasta              yamen      ramy      orange juice               5    600
# Pasta              yamen      ramy      orange juice               5    600
# ...

# %%
df['number of days'] = (1)
df
# Out:
#               first name last name favorite desserts  number of days  check  \
# favorite food
# rice                ramy     ahmed         ice cream               1    300
# rice                ramy     ahmed         ice cream               1    300
# rice                ramy     ahmed         ice cream               1    300
# fish                ramy     ahmed         ice cream               1    500
# fish                ramy     ahmed         ice cream               1    500
# fish                ramy     ahmed         ice cream               1    500
# Pasta              yamen      ramy      orange juice               1    600
# Pasta              yamen      ramy      orange juice               1    600
# Pasta              yamen      ramy      orange juice               1    600
# Pasta              yamen      ramy      orange juice               1    600
# Pasta              yamen      ramy      orange juice               1    600
# ...

# %%
df.plot(kind='bar', figsize=(12, 6))
# Out:
# <Axes: xlabel='favorite food'>

# %%
df.plot.scatter('age','check')
# Out:
# <Axes: xlabel='age', ylabel='check'>

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# Create scatter plot with regression line
sns.regplot(x='age', y='check', data=df, scatter_kws={'s': 50}, line_kws={'color': 'red'})
plt.title('Age vs Check with Regression Line')
plt.xlabel('Age')
plt.ylabel('Check')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# Cell In[27], line 6
#       3 import matplotlib.pyplot as plt
#       5 # Create scatter plot with regression line
# ----> 6 sns.regplot(x='age', y='check', data=df, scatter_kws={'s': 50}, line_kws={'color': 'red'})
#       7 plt.title('Age vs Check with Regression Line')
#       8 plt.xlabel('Age')
#
# File c:\Users\Amira.zidan\AppData\Local\anaconda3\Lib\site-packages\seaborn\regression.py:775, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     773 scatter_kws["marker"] = marker
#     774 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 775 plotter.plot(ax, scatter_kws, line_kws)
#     776 return ax
#
# ...

# %%
import numpy as np

# %%
sns.regplot(x='age', y='check', data=df, scatter_kws={'s': 50}, line_kws={'color': 'red'})
plt.title('Age vs Check with Regression Line')
plt.xlabel('Age')
plt.ylabel('Check')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# DTypePromotionError                       Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 sns.regplot(x='age', y='check', data=df, scatter_kws={'s': 50}, line_kws={'color': 'red'})
#       2 plt.title('Age vs Check with Regression Line')
#       3 plt.xlabel('Age')
#
# File c:\Users\Amira.zidan\AppData\Local\anaconda3\Lib\site-packages\seaborn\regression.py:775, in regplot(data, x, y, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     773 scatter_kws["marker"] = marker
#     774 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 775 plotter.plot(ax, scatter_kws, line_kws)
#     776 return ax
#
# ...

# %%
df.plot()
# Out:
# <Axes: xlabel='favorite food'>

# %%
df.plot(kind='line', figsize=(12, 6), x='age', y='check')
# Out:
# <Axes: xlabel='age'>

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder

# Convert 'age' column to numeric (it's currently object type)
df['age'] = pd.to_numeric(df['age'], errors='coerce')

# Prepare the data
X = df[['age']].values
y = df['check'].values

# Create and fit the model
model = LinearRegression()
model.fit(X, y)

# Print results
print(f"Coefficient: {model.coef_[0]}")
print(f"Intercept: {model.intercept_}")
print(f"R-squared: {model.score(X, y)}")
# Out:
# Coefficient: -11.576919548665257
# Intercept: 882.9832125493074
# R-squared: 0.3883075739645333

# %%
df_sorted = df.sort_values('age')
df_sorted
# Out:
#               first name last name favorite desserts  number of days  check  \
# favorite food
# Pasta              yamen      ramy      orange juice               1    600
# Pasta              yamen      ramy      orange juice               1    600
# meet               yamen      ramy      orange juice               1    600
# meet               yamen      ramy      orange juice               1    600
# meet               yamen      ramy      orange juice               1    600
# Pasta              yamen      ramy      orange juice               1    600
# Pasta              yamen      ramy      orange juice               1    600
# Pasta              yamen      ramy      orange juice               1    600
# meet               yamen      ramy      orange juice               1    600
# meet               yamen      ramy      orange juice               1    600
# chicken            malek      ramy             apple               1   1000
# ...

# %%
df.plot(kind='line', figsize=(12, 6), x='age', y='check', color='orange')
# Out:
# <Axes: xlabel='age'>

# %%
عايزة اغير اسم الملف

# %%
# Save the dataframe to a new Excel file
df.to_excel(r"Z:\food_processed.xlsx")
print("File saved as food_processed.xlsx")
# Out:
# File saved as food_processed.xlsx

# %%
import os
import shutil

# Rename the notebook file
old_name = r"Z:\Untitled.ipynb"
new_name = r"Z:\food file.ipynb"

if os.path.exists(old_name):
    shutil.move(old_name, new_name)
    print(f"Notebook renamed to: food file.ipynb")
else:
    print("Original file not found")
# Out:
# Original file not found

# %%
import os
import shutil

# Rename the notebook file from 'untitled-2.ipynb' to 'food file.ipynb'
old_notebook = r"Z:\untitled-2.ipynb"
new_notebook = r"Z:\food file.ipynb"

if os.path.exists(old_notebook):
    shutil.move(old_notebook, new_notebook)
    print("Notebook renamed to: food file.ipynb")
else:
    print("Original file not found")
# Out:
# Original file not found
